# %% [markdown]
# # Day 3 modlue 3

# %% [markdown]
# ## Examples

# %%
import pandas as pd
import datetime
data = pd.read_csv('Files/Passengers.csv')

# %%
data
# Out:
#          Month  Passengers
# 0   1949-01-01         112
# 1   1949-02-01         118
# 2   1949-03-01         132
# 3   1949-04-01         129
# 4   1949-05-01         121
# ..         ...         ...
# 139 1960-08-01         606
# 140 1960-09-01         508
# 141 1960-10-01         461
# 142 1960-11-01         390
# 143 1960-12-01         432
#
# [144 rows x 2 columns]

# %%
data['Month'] = pd.to_datetime(data['Month'])
data = data.set_index('Month')

# %%
data
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121
# ...                ...
# 1960-08-01         606
# 1960-09-01         508
# 1960-10-01         461
# 1960-11-01         390
# 1960-12-01         432
#
# [144 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
data.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
data.describe()
# Out:
#        Passengers
# count  144.000000
# mean   280.298611
# std    119.966317
# min    104.000000
# 25%    180.000000
# 50%    265.500000
# 75%    360.500000
# max    622.000000

# %%
data.resample('YE').sum().plot()
# Out:
# <Axes: xlabel='Month'>

# %%
df = pd.read_csv('Files/Germany.csv',index_col=0,parse_dates=True)

# %%
df['Year'] = df.index.year
df['Month'] = df.index.month
df['Weekday'] = df.index.day_name()

# %%
cols_to_plot = ['Consumption','Solar','Wind']
axes = df[cols_to_plot].plot(subplots=True,figsize=(10,10))
for ax in axes:
    ax.set_ylabel('Daily Totals (GwH)')

# %%
ax = df.loc['2016-01':'2016-02','Consumption'].plot()

# %%
import seaborn as sns
fig, axes = plt.subplots(3,1,figsize = (15,15),sharex=True)
for name,ax in zip(['Consumption','Solar','Wind'],axes):
    sns.boxplot(data=df,x='Month',y=name,ax=ax,palette='Set2')
    ax.set_ylabel('GWh')
    ax.set_title(name)
# Out:
# /var/folders/t4/n7hmgl3x4t37tfbxfbczj19m0000gn/T/ipykernel_32020/2788880208.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x='Month',y=name,ax=ax,palette='Set2')
# /var/folders/t4/n7hmgl3x4t37tfbxfbczj19m0000gn/T/ipykernel_32020/2788880208.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x='Month',y=name,ax=ax,palette='Set2')
# /var/folders/t4/n7hmgl3x4t37tfbxfbczj19m0000gn/T/ipykernel_32020/2788880208.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x='Month',y=name,ax=ax,palette='Set2')

# %%
import seaborn as sns
fig, axes = plt.subplots(3,1,figsize = (15,15),sharex=True)
for name,ax in zip(['Consumption','Solar','Wind'],axes):
    sns.boxplot(data=df,x='Weekday',y=name,ax=ax,palette='Set2')
    ax.set_ylabel('GWh')
    ax.set_title(name)
# Out:
# /var/folders/t4/n7hmgl3x4t37tfbxfbczj19m0000gn/T/ipykernel_32020/1902323870.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x='Weekday',y=name,ax=ax,palette='Set2')
# /var/folders/t4/n7hmgl3x4t37tfbxfbczj19m0000gn/T/ipykernel_32020/1902323870.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df,x='Weekday',y=name,ax=ax,palette='Set2')
# /var/folders/t4/n7hmgl3x4t37tfbxfbczj19m0000gn/T/ipykernel_32020/1902323870.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
import tsfresh
from tsfresh.examples.robot_execution_failures import download_robot_execution_failures, load_robot_execution_failures

# %%
download_robot_execution_failures()
timeseries, y = load_robot_execution_failures()

# %%
normal = timeseries[timeseries.id == 3]
normal.plot(x='time',kind = 'line')
plt.show()
fail = timeseries[timeseries.id == 20]
fail.plot(x='time',kind = 'line')
plt.show()

# %%
timeseries[timeseries.id==1]
# Out:
#     id  time  F_x  F_y  F_z  T_x  T_y  T_z
# 0    1     0   -1   -1   63   -3   -1    0
# 1    1     1    0    0   62   -3   -1    0
# 2    1     2   -1   -1   61   -3    0    0
# 3    1     3   -1   -1   63   -2   -1    0
# 4    1     4   -1   -1   63   -3   -1    0
# 5    1     5   -1   -1   63   -3   -1    0
# 6    1     6   -1   -1   63   -3    0    0
# 7    1     7   -1   -1   63   -3   -1    0
# 8    1     8   -1   -1   63   -3   -1    0
# 9    1     9   -1   -1   61   -3    0    0
# 10   1    10   -1   -1   61   -3    0    0
# 11   1    11   -1   -1   64   -3   -1    0
# 12   1    12   -1   -1   64   -3   -1    0
# 13   1    13   -1   -1   60   -3    0    0
# 14   1    14   -1    0   64   -2   -1    0

# %%
from tsfresh import extract_features
extracted_features = extract_features(timeseries,column_id = 'id',column_sort='time')
# Out:
# Feature Extraction: 100%|██████████| 20/20 [00:04<00:00,  4.51it/s]

# %%
timeseries.shape
# Out:
# (1320, 8)

# %%
extracted_features.shape
# Out:
# (88, 4698)

# %%
extracted_features
# Out:
#     T_x__variance_larger_than_standard_deviation  T_x__has_duplicate_max  \
# 1                                            0.0                     1.0
# 2                                            1.0                     1.0
# 3                                            1.0                     0.0
# 4                                            1.0                     1.0
# 5                                            1.0                     0.0
# ..                                           ...                     ...
# 84                                           1.0                     0.0
# 85                                           1.0                     0.0
# 86                                           1.0                     0.0
# 87                                           1.0                     0.0
# 88                                           1.0                     1.0
#
#     T_x__has_duplicate_min  T_x__has_duplicate  T_x__sum_values  \
# ...

# %%
from tsfresh.utilities.dataframe_functions import impute 
from tsfresh import select_features
extracted_features_filtered = impute(extracted_features)

# %%
extracted_features_filtered.shape
# Out:
# (88, 4698)

# %%
selected_features = select_features(extracted_features_filtered,y)

# %%
selected_features.shape
# Out:
# (88, 682)

# %% [markdown]
# ## Exs

# %% [markdown]
# ## Q1

# %%
df = pd.read_csv('Files/Birth.csv',index_col=0,parse_dates=True)
#df['Date'] = pd.to_datetime(df['Date'])
#df.set_index('Date')

# %%
df[df.index.month==1]
# Out:
#             Births
# Date
# 1959-01-01      35
# 1959-01-02      32
# 1959-01-03      30
# 1959-01-04      31
# 1959-01-05      44
# 1959-01-06      29
# 1959-01-07      45
# 1959-01-08      43
# 1959-01-09      38
# 1959-01-10      27
# 1959-01-11      38
# 1959-01-12      33
# 1959-01-13      55
# 1959-01-14      47
# 1959-01-15      45
# 1959-01-16      37
# 1959-01-17      50
# 1959-01-18      43
# 1959-01-19      41
# 1959-01-20      52
# 1959-01-21      34
# 1959-01-22      53
# 1959-01-23      39
# 1959-01-24      32
# 1959-01-25      37
# 1959-01-26      43
# 1959-01-27      39
# 1959-01-28      35
# 1959-01-29      44
# 1959-01-30      38
# 1959-01-31      24

# %%
df.describe()
# Out:
#            Births
# count  365.000000
# mean    41.980822
# std      7.348257
# min     23.000000
# 25%     37.000000
# 50%     42.000000
# 75%     46.000000
# max     73.000000

# %%
df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df.resample('ME').sum().plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Q3

# %%
df = pd.read_csv('Files/KC1.csv')
# Out:
#      PPD  CBO  DIT  LCOM  NOC  DOC  FIN  RFC  WMC  Faulty
# 0      0   24    4   100    0    0    2  110   73       1
# 1      0   19    4   100    0    0    3   78   30       1
# 2    100   13    1    88    0    0    0   99   99       1
# 3      0   21    4   100    0    0    2   68   30       1
# 4      5   17    2    90    0    0    1   69   36       1
# ..   ...  ...  ...   ...  ...  ...  ...  ...  ...     ...
# 140    0    1    2     0    0    0    1    2    2       0
# 141   17    1    4   100    0    0    1  198   24       0
# 142    0    0    3     0    0    0    2   60    5       0
# 143    0    0    1    98    0    0    0   37   34       0
# 144    0    0    1   100    0    0    0    7    7       0
#
# [145 rows x 10 columns]

# %%
from sklearn.feature_selection import SelectKBest,f_classif
from sklearn.preprocessing import StandardScaler

X = df.loc[:, df.columns != 'Faulty']
y = df.loc[:,df.columns == 'Faulty']

scaler = StandardScaler()
x = scaler.fit_transform(X)

fit = SelectKBest(f_classif, k=3)
X_new = fit.fit_transform(x, y)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
X_new.shape
# Out:
# (145, 3)

# %%
fit.get_feature_names_out()
# Out:
# array(['x1', 'x7', 'x8'], dtype=object)

# %%
df
# Out:
#      PPD  CBO  DIT  LCOM  NOC  DOC  FIN  RFC  WMC  Faulty
# 0      0   24    4   100    0    0    2  110   73       1
# 1      0   19    4   100    0    0    3   78   30       1
# 2    100   13    1    88    0    0    0   99   99       1
# 3      0   21    4   100    0    0    2   68   30       1
# 4      5   17    2    90    0    0    1   69   36       1
# ..   ...  ...  ...   ...  ...  ...  ...  ...  ...     ...
# 140    0    1    2     0    0    0    1    2    2       0
# 141   17    1    4   100    0    0    1  198   24       0
# 142    0    0    3     0    0    0    2   60    5       0
# 143    0    0    1    98    0    0    0   37   34       0
# 144    0    0    1   100    0    0    0    7    7       0
#
# [145 rows x 10 columns]

# %%
df.loc[:,df.columns=='Faulty']
# Out:
#      Faulty
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ..      ...
# 140       0
# 141       0
# 142       0
# 143       0
# 144       0
#
# [145 rows x 1 columns]
